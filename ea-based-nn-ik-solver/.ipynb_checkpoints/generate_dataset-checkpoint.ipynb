# %% [markdown]
# ### Libraries

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import *

# %% [markdown]
# ### Dataset

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "3DoF-R"
q_lim = torch.tensor([[-torch.pi, torch.pi],
                      [-torch.pi, torch.pi],
                      [-torch.pi, torch.pi]])

# generate dataset with a specified number of samples
n_samples = 10000
data_position = []
for _ in range(n_samples):
    t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
    DH = get_DH(robot_choice, t)
    T = forward_kinematics(DH)
    if robot_choice == "3DoF-R":
        # x,y,t1,t2,t3 where x,y (m) and t (rad)
        data_position.append(torch.cat([T[:2,-1], t]).numpy())
      
data_position_a = np.array(data_position)


# save dataset
if robot_choice == "3DoF-R":
    header = ["x","y","t1","t2","t3"]
    
df = pd.DataFrame(data_position_a)
df.to_csv("data_"+robot_choice+".csv",
          index=False,
          header=header)

# %% [markdown]
# ### Visualize dataset

# %%
fig, ax = plt.subplots()
ax.scatter(data_position_a[:,0], data_position_a[:,1],s=1, marker='o', c='b')
ax.scatter(0,0,s=20, marker='o', c='r')
ax.set(xlabel='x(m)', ylabel='y(m)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.legend(["robot position","robot base"])
ax.grid()

# %% [markdown]
# # Testing

# %%
import pygad

# %%
import pygad.torchga as torchga

# %%
import torch.nn

input_layer = torch.nn.Linear(2, 2)
relu_layer = torch.nn.ReLU()
output_layer = torch.nn.Linear(2, 3)

model = torch.nn.Sequential(input_layer,
                            relu_layer,
                            output_layer)

# %%
torch_ga = torchga.TorchGA(model=model, num_solutions=10)

# %%
training_data = data_position_a[:8000, :2]
testing_data = data_position_a[8000:, :2]

training_targets = data_position_a[:8000, 2:]
testing_targets = data_position_a[8000:, 2:]

# %%
loss_function = torch.nn.L1Loss()

def fitness_func(ga_instance, solution, solution_idx):
    global data_inputs, data_outputs, torch_ga, model, loss_function

    model_weights_dict = torchga.model_weights_as_dict(model=model,
                                                         weights_vector=solution)

    # Use the current solution as the model parameters.
    model.load_state_dict(model_weights_dict)

    predictions = model(data_inputs)

    solution_fitness = 1.0 / (loss_function(predictions, data_outputs).detach().numpy() + 0.00000001)

    return solution_fitness

# %%
def callback_generation(ga_instance):
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))

# %%
num_generations = 250
num_parents_mating = 5
initial_population = torch_ga.population_weights

ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       initial_population=initial_population,
                       fitness_func=fitness_func,
                       on_generation=callback_generation)

# %%
ga_instance.run()
# Out:
# name 'data_inputs' is not defined
# Traceback (most recent call last):
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "/tmp/ipykernel_44252/646149362.py", line 12, in fitness_func
#     predictions = model(data_inputs)
# NameError: name 'data_inputs' is not defined
# ERROR:pygad.pygad:name 'data_inputs' is not defined
# Traceback (most recent call last):
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "/tmp/ipykernel_44252/646149362.py", line 12, in fitness_func
#     predictions = model(data_inputs)
# NameError: name 'data_inputs' is not defined
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py", line 1688, in cal_pop_fitness
#     fitness = self.fitness_func(self, sol, sol_idx)
#   File "/tmp/ipykernel_44252/646149362.py", line 12, in fitness_func
#     predictions = model(data_inputs)
# NameError: name 'data_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_44252/2488311474.py", line 1, in <module>
#     ga_instance.run()
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py", line 1891, in run
#     self.last_generation_fitness = self.cal_pop_fitness()
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py", line 1848, in cal_pop_fitness
#     sys.exit(-1)
# SystemExit: -1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/macula/SMATousi/.conda/envs/mac-deep/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py in cal_pop_fitness(self)
#    1687                         if self.fitness_batch_size in [1, None]:
# -> 1688                             fitness = self.fitness_func(self, sol, sol_idx)
#    1689                             if type(fitness) in GA.supported_int_float_types:
#
# /tmp/ipykernel_44252/646149362.py in fitness_func(ga_instance, solution, solution_idx)
#      11
# ---> 12     predictions = model(data_inputs)
#      13
#
# NameError: name 'data_inputs' is not defined
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_44252/2488311474.py in <module>
# ----> 1 ga_instance.run()
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py in run(self)
#    1890             # Measuring the fitness of each chromosome in the population. Save the fitness in the last_generation_fitness attribute.
# -> 1891             self.last_generation_fitness = self.cal_pop_fitness()
#    1892
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/pygad/pygad.py in cal_pop_fitness(self)
#    1847             self.logger.exception(ex)
# -> 1848             sys.exit(-1)
#    1849         return pop_fitness
#
# SystemExit: -1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2069                            'the full traceback.\n']
#    2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2071                                                                      value))
#    2072                 else:
#    2073                     try:
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.conda/envs/mac-deep/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
pygad.__version__
# Out:
# '3.0.1'
