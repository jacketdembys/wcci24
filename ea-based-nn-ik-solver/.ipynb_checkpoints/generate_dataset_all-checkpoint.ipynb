# %% [markdown]
# ### Libraries

# %%
# %matplotlib widget
from mpl_toolkits.mplot3d import Axes3D

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from utils import *

# %%
#!pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 775.5 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipython<9 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipympl) (8.17.2)
# Requirement already satisfied: numpy in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipympl) (1.26.1)
# Collecting ipython-genutils (from ipympl)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pillow in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipympl) (10.1.0)
# Requirement already satisfied: traitlets<6 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipympl) (5.13.0)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl)
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipympl) (3.8.0)
# Requirement already satisfied: decorator in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (2.16.1)
# Requirement already satisfied: stack-data in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.0)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets<9,>=7.6.0->ipympl)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets<9,>=7.6.0->ipympl)
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.9)
# Requirement already satisfied: six>=1.5 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in /home/retina/dembysj/.conda/envs/wcci_24/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 77.1 kB/s eta 0:00:00 0:00:01
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 348.9 kB/s eta 0:00:00 0:00:01
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: ipython-genutils, widgetsnbextension, jupyterlab-widgets, ipywidgets, ipympl
# Successfully installed ipympl-0.9.3 ipython-genutils-0.2.0 ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 widgetsnbextension-4.0.9

# %%
print("Pytorch version: ... {} ".format(torch.__version__))
print("Python version ... {}".format(sys.version))
# Out:
# Pytorch version: ... 2.0.0+cu117
# Python version ... 3.11.5 (main, Sep 11 2023, 13:54:46) [GCC 11.2.0]

# %%
## Conversion from PyTorch 3D GitHub repository

def _angle_from_tan(
    axis: str, other_axis: str, data, horizontal: bool, tait_bryan: bool
) -> torch.Tensor:
    """
    Extract the first or third Euler angle from the two members of
    the matrix which are positive constant times its sine and cosine.

    Args:
        axis: Axis label "X" or "Y or "Z" for the angle we are finding.
        other_axis: Axis label "X" or "Y or "Z" for the middle axis in the
            convention.
        data: Rotation matrices as tensor of shape (..., 3, 3).
        horizontal: Whether we are looking for the angle for the third axis,
            which means the relevant entries are in the same row of the
            rotation matrix. If not, they are in the same column.
        tait_bryan: Whether the first and third axes in the convention differ.

    Returns:
        Euler Angles in radians for each matrix in data as a tensor
        of shape (...).
    """

    i1, i2 = {"X": (2, 1), "Y": (0, 2), "Z": (1, 0)}[axis]
    if horizontal:
        i2, i1 = i1, i2
    even = (axis + other_axis) in ["XY", "YZ", "ZX"]
    if horizontal == even:
        return torch.atan2(data[..., i1], data[..., i2])
    if tait_bryan:
        return torch.atan2(-data[..., i2], data[..., i1])
    return torch.atan2(data[..., i2], -data[..., i1])

def _index_from_letter(letter: str) -> int:
    if letter == "X":
        return 0
    if letter == "Y":
        return 1
    if letter == "Z":
        return 2
    raise ValueError("letter must be either X, Y or Z.")

def matrix_to_euler_angles(matrix: torch.Tensor, convention: str) -> torch.Tensor:
    """
    Convert rotations given as rotation matrices to Euler angles in radians.

    Args:
        matrix: Rotation matrices as tensor of shape (..., 3, 3).
        convention: Convention string of three uppercase letters.

    Returns:
        Euler angles in radians as tensor of shape (..., 3).
    """
    if len(convention) != 3:
        raise ValueError("Convention must have 3 letters.")
    if convention[1] in (convention[0], convention[2]):
        raise ValueError(f"Invalid convention {convention}.")
    for letter in convention:
        if letter not in ("X", "Y", "Z"):
            raise ValueError(f"Invalid letter {letter} in convention string.")
    if matrix.size(-1) != 3 or matrix.size(-2) != 3:
        raise ValueError(f"Invalid rotation matrix shape {matrix.shape}.")
    i0 = _index_from_letter(convention[0])
    i2 = _index_from_letter(convention[2])
    tait_bryan = i0 != i2
    if tait_bryan:
        central_angle = torch.asin(
            matrix[..., i0, i2] * (-1.0 if i0 - i2 in [-1, 2] else 1.0)
        )
    else:
        central_angle = torch.acos(matrix[..., i0, i0])

    o = (
        _angle_from_tan(
            convention[0], convention[1], matrix[..., i2], False, tait_bryan
        ),
        central_angle,
        _angle_from_tan(
            convention[2], convention[1], matrix[..., i0, :], True, tait_bryan
        ),
    )
    return torch.stack(o, -1)

# %% [markdown]
# ### Generate 2DoF Dataset

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "2DoF-2R"
"""
q_lim = torch.tensor([[-torch.pi, torch.pi],
                      [-torch.pi, torch.pi],
                      [-torch.pi, torch.pi]])
"""

q_lim = torch.tensor([[0, torch.pi],
                      [0, torch.pi]])

# generate dataset with a specified number of samples
n_samples = 10000
data_position = []
for _ in range(n_samples):
    t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
    DH = get_DH(robot_choice, t)
    T = forward_kinematics(DH)
    if robot_choice == "2DoF-2R":
        # x,y,t1,t2,t3 where x,y (m) and t (rad)
        data_position.append(torch.cat([T[:2,-1], t]).numpy())
      
data_position_a = np.array(data_position)


# save dataset
if robot_choice == "2DoF-2R":
    header = ["x","y","t1","t2"]
    
df = pd.DataFrame(data_position_a)
df.to_csv("data_"+robot_choice+".csv",
          index=False,
          header=header)

# %% [markdown]
# ### Visualize 2DoF Dataset

# %%
fig, ax = plt.subplots()
ax.scatter(data_position_a[:,0], data_position_a[:,1],s=1, marker='o', c='b')
ax.scatter(0,0,s=20, marker='o', c='r')
ax.set(xlabel='x(m)', ylabel='y(m)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.legend(["robot position","robot base"])
ax.grid()

# %%
### Make it a classification

# %% [markdown]
# ### Generate 3DoF Dataset

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "3DoF-3R-2"
"""
q_lim = torch.tensor([[-torch.pi, torch.pi],
                      [-torch.pi, torch.pi],
                      [-torch.pi, torch.pi]])
"""

q_lim = torch.tensor([[0, torch.pi],
                      [0, torch.pi],
                      [0, torch.pi]])

# generate dataset with a specified number of samples
n_samples = 10000
data_position = []
for _ in range(n_samples):
    t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
    DH = get_DH(robot_choice, t)
    T = forward_kinematics(DH)
    if robot_choice == "3DoF-3R-2":
        # x,y,t1,t2,t3 where x,y (m) and t (rad)
        data_position.append(torch.cat([T[:2,-1], t]).numpy())
      
data_position_a = np.array(data_position)


# save dataset
if robot_choice == "3DoF-3R-2":
    header = ["x","y","t1","t2","t3"]
    
df = pd.DataFrame(data_position_a)
df.to_csv("data_"+robot_choice+".csv",
          index=False,
          header=header)

# %% [markdown]
# ### Visualize 3DoF Dataset

# %%
fig, ax = plt.subplots()
ax.scatter(data_position_a[:,0], data_position_a[:,1],s=1, marker='o', c='b')
ax.scatter(0,0,s=20, marker='o', c='r')
ax.set(xlabel='x(m)', ylabel='y(m)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.legend(["robot position","robot base"])
ax.grid()

# %% [markdown]
# ### Generate 4DoF Dataset

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "4DoF-2RPR"
"""
q_lim = torch.tensor([[0, torch.deg2rad(torch.tensor(180))],
                      [torch.deg2rad(torch.tensor(0)), torch.deg2rad(torch.tensor(180))],
                      [torch.tensor(0.01), torch.tensor(0.25)],
                      [torch.deg2rad(torch.tensor(30)), torch.deg2rad(torch.tensor(60))]])
"""

q_lim = torch.tensor([[0, torch.deg2rad(torch.tensor(360))],
                      [torch.deg2rad(torch.tensor(0)), torch.deg2rad(torch.tensor(360))],
                      [torch.tensor(0.01), torch.tensor(0.5)],
                      [torch.deg2rad(torch.tensor(0)), torch.deg2rad(torch.tensor(360))]])

# generate dataset with a specified number of samples
n_samples = 100000
data_position = []
for _ in range(n_samples):
    t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
    DH = get_DH(robot_choice, t)
    T = forward_kinematics(DH)
    if robot_choice == "4DoF-2RPR":
        # x,y,t1,t2,t3 where x,y (m) and t (rad)
        data_position.append(torch.cat([T[:3,-1], t]).numpy())
      
data_position_a = np.array(data_position)


# save dataset
if robot_choice == "4DoF-2RPR":
    header = ["x","y","z","t1","t2","t3","t4"]
    
df = pd.DataFrame(data_position_a)
df.to_csv("data_"+robot_choice+"_"+str(n_samples)+"_2.csv",
          index=False,
          header=header)

data_position_a = data_position_a * 1000

# %%
### Visualize 4DoF Dataset
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.scatter(data_position_a[:,0], data_position_a[:,1], data_position_a[:,2], s=2, c='b', marker='.')
ax.scatter(0,0,0,s=20, marker='o', c='r')
ax.legend(["robot position","robot base"])
ax.set(xlabel='x(m)', ylabel='y(m)', zlabel='z(m)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.view_init(60, 25)
plt.show()

# %% [markdown]
# ### Generate 6DoF Dataset

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "6DoF-6R-Puma260"
"""
q_lim = torch.tensor([[torch.deg2rad(torch.tensor(-180)), torch.deg2rad(torch.tensor(110))],
                      [torch.deg2rad(torch.tensor(-75)), torch.deg2rad(torch.tensor(240))],
                      [torch.deg2rad(torch.tensor(-235)), torch.deg2rad(torch.tensor(60))],
                      [torch.deg2rad(torch.tensor(-580)), torch.deg2rad(torch.tensor(40))],
                      [torch.deg2rad(torch.tensor(-30)), torch.deg2rad(torch.tensor(200))],
                      [torch.deg2rad(torch.tensor(-215)), torch.deg2rad(torch.tensor(295))]])
"""

for scale in range(1,11,1):
    q_lim = torch.tensor([[torch.deg2rad(torch.tensor(-180)), torch.deg2rad(torch.tensor(110))],
                          [torch.deg2rad(torch.tensor(-75)), torch.deg2rad(torch.tensor(240))],
                          [torch.deg2rad(torch.tensor(-235)), torch.deg2rad(torch.tensor(60))],
                          [torch.deg2rad(torch.tensor(-580)), torch.deg2rad(torch.tensor(40))],
                          [torch.deg2rad(torch.tensor(-30)), torch.deg2rad(torch.tensor(200))],
                          [torch.deg2rad(torch.tensor(-215)), torch.deg2rad(torch.tensor(295))]])

    q_lim = q_lim/scale
    
    # generate dataset with a specified number of samples
    n_samples = 10000
    print_steps = 10
    data_position = []
    for s in range(n_samples):
        t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
        #print(t)
        DH = get_DH(robot_choice, t)
        #print(DH) 
        T = forward_kinematics(DH)
        R = T[:3,:3]       
        #print(T)
        rpy = matrix_to_euler_angles(R, "XYZ")
        #print(rpy)
        #print()
    
        #sys.exit()
    
        if s%(n_samples/print_steps) == 0:
            print("Generated [{}] samples ...".format(s))
        
        if robot_choice == "6DoF-6R-Puma260":
            # x,y,z,R,P,Y,t1,t2,t3,t4,t5,t6 where x,y,z (m) and t (rad)
            data_position.append(torch.cat([T[:3,-1], rpy, t]).numpy())
          
    data_position_a = np.array(data_position)
    
    
    # save dataset
    if robot_choice == "6DoF-6R-Puma260":
        header = ["x", "y", "z","R","P","Y","t1", "t2", "t3", "t4", "t5", "t6"]
        
    df = pd.DataFrame(data_position_a)
    df.to_csv("data_"+robot_choice+"_"+str(n_samples)+"_qlim_scale_"+str(int(scale))+".csv",
              index=False,
              header=header)
    
    data_position_a = data_position_a * 1000
    
    print("Data generation done!")
# Out:
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!
# Generated [0] samples ...
# Generated [1000] samples ...
# Generated [2000] samples ...
# Generated [3000] samples ...
# Generated [4000] samples ...
# Generated [5000] samples ...
# Generated [6000] samples ...
# Generated [7000] samples ...
# Generated [8000] samples ...
# Generated [9000] samples ...
# Data generation done!

# %%
q_lim
# Out:
# tensor([[-0.3142,  0.1920],
#         [-0.1309,  0.4189],
#         [-0.4102,  0.1047],
#         [-1.0123,  0.0698],
#         [-0.0524,  0.3491],
#         [-0.3752,  0.5149]])

# %%
### Visualize 4DoF Dataset
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.scatter(data_position_a[:,0], data_position_a[:,1], data_position_a[:,2], s=2, c='b', marker='.')
ax.scatter(0,0,0,s=20, marker='o', c='r')
ax.legend(["robot position","robot base"])
ax.set(xlabel='x(mm)', ylabel='y(mm)', zlabel='z(mm)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.view_init(60, 25)
plt.show()

# %% [markdown]
# ### Generate 7DoF Dataset - Panda Franka

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "7DoF-7R-Panda"
"""
q_lim = torch.tensor([[torch.deg2rad(torch.tensor(-180)), torch.deg2rad(torch.tensor(110))],
                      [torch.deg2rad(torch.tensor(-75)), torch.deg2rad(torch.tensor(240))],
                      [torch.deg2rad(torch.tensor(-235)), torch.deg2rad(torch.tensor(60))],
                      [torch.deg2rad(torch.tensor(-580)), torch.deg2rad(torch.tensor(40))],
                      [torch.deg2rad(torch.tensor(-30)), torch.deg2rad(torch.tensor(200))],
                      [torch.deg2rad(torch.tensor(-215)), torch.deg2rad(torch.tensor(295))]])
"""

for scale in range(2,12,2):
    q_lim = torch.tensor([[torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))],
                          [torch.deg2rad(torch.tensor(-101)), torch.deg2rad(torch.tensor(101))],
                          [torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))],
                          [torch.deg2rad(torch.tensor(-176)), torch.deg2rad(torch.tensor(-4))],
                          [torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))],
                          [torch.deg2rad(torch.tensor(-1)), torch.deg2rad(torch.tensor(215))],
                          [torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))]])

    #q_lim = q_lim/scale
    q_lim = q_lim*(scale/10)

    print("\njoint limits for scale {}:\n{}".format(scale/10, q_lim))
    
    # generate dataset with a specified number of samples
    n_samples = 100000000
    print_steps = 10
    data_position = []
    for s in range(n_samples):
        t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
        #print(t)
        DH = get_DH(robot_choice, t)
        #print(DH) 
        T = forward_kinematics(DH)
        R = T[:3,:3]       
        #print(T)
        rpy = matrix_to_euler_angles(R, "XYZ")
        #print(rpy)
        #print()
    
        #sys.exit()
    
        if s%(n_samples/print_steps) == 0:
            print("Generated [{}] samples ...".format(s))
        
        if robot_choice == "7DoF-7R-Panda":
            # x,y,z,R,P,Y,t1,t2,t3,t4,t5,t6,t7 where x,y,z (m) and t (rad)
            data_position.append(torch.cat([T[:3,-1], rpy, t]).numpy())
          
    data_position_a = np.array(data_position)
    
    
    # save dataset
    if robot_choice == "7DoF-7R-Panda":
        header = ["x", "y", "z","R","P","Y","t1", "t2", "t3", "t4", "t5", "t6", "t7"]
        
    df = pd.DataFrame(data_position_a)
    df.to_csv("datasets/"+robot_choice+"/data_"+robot_choice+"_"+str(n_samples)+"_qlim_scale_"+str(int(scale))+".csv",
              index=False,
              header=header)
    
    data_position_a = data_position_a * 1000
    
    print("Data generation done!")
# Out:
# joint limits for scale 0.2:
# tensor([[-0.5794,  0.5794],
#         [-0.3526,  0.3526],
#         [-0.5794,  0.5794],
#         [-0.6144, -0.0140],
#         [-0.5794,  0.5794],
#         [-0.0035,  0.7505],
#         [-0.5794,  0.5794]])
# Generated [0] samples ...
# Generated [10000000] samples ...
# Generated [20000000] samples ...
# Generated [30000000] samples ...

# %%
### Visualize 4DoF Dataset
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.scatter(data_position_a[:,0], data_position_a[:,1], data_position_a[:,2], s=2, c='b', marker='.')
ax.scatter(0,0,0,s=20, marker='o', c='r')
ax.legend(["robot position","robot base"])
ax.set(xlabel='x(mm)', ylabel='y(mm)', zlabel='z(mm)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.view_init(60, 25)
plt.show()

# %% [markdown]
# ### Generate 7DoF Dataset - Panda Franka (trajectory-based dataset)

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "7DoF-7R-Panda"
"""
q_lim = torch.tensor([[torch.deg2rad(torch.tensor(-180)), torch.deg2rad(torch.tensor(110))],
                      [torch.deg2rad(torch.tensor(-75)), torch.deg2rad(torch.tensor(240))],
                      [torch.deg2rad(torch.tensor(-235)), torch.deg2rad(torch.tensor(60))],
                      [torch.deg2rad(torch.tensor(-580)), torch.deg2rad(torch.tensor(40))],
                      [torch.deg2rad(torch.tensor(-30)), torch.deg2rad(torch.tensor(200))],
                      [torch.deg2rad(torch.tensor(-215)), torch.deg2rad(torch.tensor(295))]])
"""

#for scale in range(2,12,2):
scale = 10
q_lim = torch.tensor([[torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))],
                      [torch.deg2rad(torch.tensor(-101)), torch.deg2rad(torch.tensor(101))],
                      [torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))],
                      [torch.deg2rad(torch.tensor(-176)), torch.deg2rad(torch.tensor(-4))],
                      [torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))],
                      [torch.deg2rad(torch.tensor(-1)), torch.deg2rad(torch.tensor(215))],
                      [torch.deg2rad(torch.tensor(-166)), torch.deg2rad(torch.tensor(166))]])

#q_lim = q_lim/scale
q_lim = q_lim*(scale/10)

print("\njoint limits for scale {}:\n{}".format(scale/10, q_lim))

# generate dataset with a specified number of samples
n_traj = 100000
n_traj_steps = 250
#n_samples = 100000000
print_steps = 10
data_position = []
for s in range(n_traj):
    t0 = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
    DH = get_DH(robot_choice, t0)
    T = forward_kinematics(DH)
    R = T[:3,:3]       
    rpy = matrix_to_euler_angles(R, "XYZ")
    #data_position.append(torch.cat([T[:3,-1], rpy, t0]).numpy())  

    D_current = torch.cat([T[:3,-1], rpy])
    Q_current = t0

    #print(t0)
    t = t0
    for i in range(n_traj_steps):
        t += torch.deg2rad(torch.tensor(1.0)) 
        #print(t)
        DH = get_DH(robot_choice, t)
        T = forward_kinematics(DH)
        R = T[:3,:3]       
        rpy = matrix_to_euler_angles(R, "XYZ")

        D_previous = D_current
        Q_previous = Q_current
        D_current = torch.cat([T[:3,-1], rpy])
        Q_current = t
        
        data_position.append(torch.cat([D_previous, Q_previous, D_current, Q_current]).numpy()) 


    if s%(n_traj/print_steps) == 0:
        print("Generated [{}] trajectories with {} samples...".format(s, i+1))
    
data_position_a = np.array(data_position)


# save dataset
if robot_choice == "7DoF-7R-Panda":
    header = ["x_p", "y_p", "z_p","R_p","P_p","Y_p",
              "t1_p", "t2_p", "t3_p", "t4_p", "t5_p", "t6_p", "t7_p",
              "x_c", "y_c", "z_c","R_c","P_c","Y_c",
              "t1_c", "t2_c", "t3_c", "t4_c", "t5_c", "t6_c", "t7_c"]
    
df = pd.DataFrame(data_position_a)
n_samples = data_position_a.shape[0]
path = "~/Documents/Research/WCCI2024/"
df.to_csv(path+"datasets/"+robot_choice+"/data_"+robot_choice+"_"+str(n_samples)+"_qlim_scale_"+str(int(scale))+"_seq.csv",
          index=False,
          header=header)

data_position_a[:,:3] = data_position_a[:,:3] * 1000

print("Data generation done! - {} samples each".format(n_samples))
# Out:
# joint limits for scale 1.0:
# tensor([[-2.8972,  2.8972],
#         [-1.7628,  1.7628],
#         [-2.8972,  2.8972],
#         [-3.0718, -0.0698],
#         [-2.8972,  2.8972],
#         [-0.0175,  3.7525],
#         [-2.8972,  2.8972]])
# Generated [0] trajectories with 100 samples...
# Generated [1000] trajectories with 100 samples...
# Generated [2000] trajectories with 100 samples...
# Generated [3000] trajectories with 100 samples...
# Generated [4000] trajectories with 100 samples...
# Generated [5000] trajectories with 100 samples...
# Generated [6000] trajectories with 100 samples...
# Generated [7000] trajectories with 100 samples...
# Generated [8000] trajectories with 100 samples...
# Generated [9000] trajectories with 100 samples...
# Data generation done! - 1000000 samples each

# %%
i#mport ipympl
#import matplotlib.pyplot as plt
vis_traj = 1

### Visualize 4DoF Dataset
fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection='3d')
ax.scatter(data_position_a[:vis_traj*100,0], data_position_a[:vis_traj*100,1], data_position_a[:vis_traj*100,2], s=4, c='b', marker='.')
ax.scatter(0,0,0,s=20, marker='o', c='r')
ax.legend(["robot position","robot base"])
ax.set(xlabel='x(mm)', ylabel='y(mm)', zlabel='z(mm)',
       title='Visualization of '+robot_choice+ ' dataset')
ax.view_init(60, 25)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(data_position_a[:vis_traj*100,0])
print(data_position_a[:vis_traj*100,1])
print(data_position_a[:vis_traj*100,2])
# Out:
# [-369.68527   -381.48044   -392.72864   -403.40112   -413.4705
#  -422.91034   -431.696     -439.80408   -447.21277   -453.90198
#  -459.85324   -465.04987   -469.47687   -473.12128   -475.97177
#  -478.01892   -479.25504   -479.6746    -479.27332   -478.04922
#  -476.00195   -473.13278   -469.44498   -464.94305   -459.6335
#  -453.52448   -446.6254    -438.9477    -430.50372   -421.3079
#  -411.3757    -400.72418   -389.37186   -377.33847   -364.64523
#  -351.3147    -337.3708    -322.8385    -307.74445   -292.1162
#  -275.9829    -259.37457   -242.32283   -224.86014   -207.02037
#  -188.83836   -170.35022   -151.59299   -132.60472   -113.42449
#   -94.092186   -74.648674   -55.135387   -35.594627   -16.06908
#     3.3978746   22.762663    41.981346    61.009865    79.804054
#    98.32001    116.51386    134.3424     151.76279    168.7329
#   185.21146    201.1582     216.53398    231.30098    245.42284
#   258.8648     271.59396    283.57904    294.79105    305.20306
#   314.7905     323.53104    331.405      338.39526    344.48734
#   349.66962    353.93317    357.27197    359.68292    361.16602
#   361.72397    361.3625     360.0905     357.9195     354.86417
#   350.94186    346.17288    340.58014    334.18924    327.0285
#   319.1287     310.52283    301.24622    291.33655    280.8332   ]
# [ 364.6888    348.217     331.25305   313.82013   295.94296   277.6479
#   258.96295   239.91748   220.54205   200.86852   180.92967   160.75935
#   140.39209   119.8632     99.2085     78.46429    57.66716    36.854015
#    16.061842   -4.672326  -25.311493  -45.818718  -66.15744   -86.29119
#  -106.184006 -125.80024  -145.10461  -164.06262  -182.64005  -200.80347
#  -218.52007  -235.75761  -252.4848   -268.67087  -284.28607  -299.3014
#  -313.68866  -327.4209   -340.47174  -352.81613  -364.43002  -375.29047
#  -385.37567  -394.6652   -403.13995  -410.7821   -417.57523  -423.50473
#  -428.55725  -432.72128  -435.98718  -438.34686  -439.7943   -440.32532
#  -439.93808  -438.63242  -436.41074  -433.27725  -429.23868  -424.30426
#  -418.4851   -411.79498  -404.2501   -395.86884  -386.6721   -376.68317
#  -365.92758  -354.4333   -342.23062  -329.3518   -315.83136  -301.706
#  -287.01413  -271.79617  -256.09424  -239.95213  -223.41492  -206.52927
#  -189.34288  -171.9045   -154.26372  -136.47092  -118.5769   -100.63295
#   -82.69025   -64.80029   -47.014133  -29.382616  -11.95582     5.216606
#    22.08621    38.60553    54.728302   70.409744   85.60662   100.2775
#   114.38273   127.88471   140.74811   152.93967 ]
# [183.51817  178.91312  174.42068  170.04526  165.79048  161.65932
#  157.654    153.7762   150.02686  146.40634  142.91446  139.55046
#  136.31308  133.20052  130.21066  127.340866 124.58822  121.9494
#  119.42094  116.99905  114.67968  112.45872  110.33202  108.29521
#  106.34388  104.473816 102.68063  100.96015   99.30823   97.72091
#   96.19442   94.725044  93.30949   91.944565  90.62738   89.35531
#   88.12599   86.93741   85.78781   84.67578   83.60021   82.56025
#   81.55548   80.58566   79.65097   78.751686  77.88851   77.06238
#   76.27447   75.52619   74.819145  74.15506   73.53599   72.96398
#   72.441246  71.97014   71.55307   71.19248   70.8908    70.65057
#   70.47425   70.3642    70.32278   70.35224   70.4548    70.632454
#   70.88697   71.22019   71.633575  72.128456  72.70597   73.367004
#   74.1122    74.94203   75.85658   76.85593   77.93959   79.10698
#   80.35732   81.68941   83.10186   84.5931    86.16113   87.803856
#   89.51886   91.30345   93.15485   95.06988   97.04533   99.07758
#  101.16297  103.29765  105.47751  107.69835  109.95575  112.24522
#  114.56212  116.901634 119.25897  121.62908 ]

# %%
### Randomly split in test, train, val trajectories (methods 1)
np.random.seed(0)

# generate trajectory-based indices
n_samples = data_position_a.shape[0]
inds = []
for i in range(n_samples):
    if (i+1)%100 == 0:
        inds.append(i)

inds = np.array(inds)

# randomly permutate trajectory-based indices
inds_perm = np.random.permutation(inds)

# select the trajectories
inds_train = inds_perm[:int(0.8*n_traj)]
data_train = []
for i in inds_train:
    for j in range(i,i-100,-1):
        data_train.append(data_position_a[j,:])

data_train = np.array(data_train)


inds_val = inds[int(0.8*n_traj):int(0.9*n_traj)]
data_val = []
for i in inds_val:
    for j in range(i,i-100,-1):
        data_val.append(data_position_a[j,:])

data_val = np.array(data_val)


inds_test = inds[int(0.9*n_traj):]
data_test = []
for i in inds_test:
    for j in range(i,i-100,-1):
        data_test.append(data_position_a[j,:])

data_test = np.array(data_test)


print(data_position_a.shape)
print(data_train.shape)
print(data_val.shape)
print(data_test.shape)
print()


### Randomly split in test, train, val trajectories (methods 2)
data_train = data_position_a[:int(0.8*n_samples),:]
data_val = data_position_a[int(0.8*n_samples):int(0.9*n_samples),:]
data_test = data_position_a[int(0.9*n_samples):,:]


print(data_position_a.shape)
print(data_train.shape)
print(data_val.shape)
print(data_test.shape)
print()


print(data_train[:100,:])
# Out:
# (1000000, 26)
# (800000, 26)
# (100000, 26)
# (100000, 26)
#
# (1000000, 26)
# (800000, 26)
# (100000, 26)
# (100000, 26)
#
# [[ -369.68527     364.6888      183.51817   ... -1098.4338
#    2390.4202      -39.950275 ]
#  [ -381.48044     348.217       178.91312   ... -1080.9806
#    2407.8733      -22.49698  ]
#  [ -392.72864     331.25305     174.42068   ... -1063.5272
#    2425.3267       -5.0436893]
#  ...
#  [  301.24622     127.88471     116.901634  ...   594.53613
#    4083.3801     1653.0203   ]
#  [  291.33655     140.74811     119.25897   ...   611.98944
#    4100.8335     1670.4736   ]
#  [  280.8332      152.93967     121.62908   ...   629.44275
#    4118.2866     1687.9269   ]]

# %%
-180%360
# Out:
# 180

# %%
import numpy
import torch 

x = torch.rand(100,3)
mapping_size = 32
B_dict = {}
B_dict['basic'] = torch.eye(mapping_size,3)
B = B_dict['basic']

# %%
def input_mapping(x, B):
    if B is None:
        return x
    else:
        x_proj = torch.matmul((2*torch.pi*x), B.T)
        print(x.shape)
        print(B.shape)
        print(x_proj.shape)
        print(torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1).shape)
    
        return torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)

xB = input_mapping(x,B)
# Out:
# torch.Size([100, 3])
# torch.Size([32, 3])
# torch.Size([100, 32])
# torch.Size([100, 64])

# %% [markdown]
# ### Classification

# %%
# seed random generator
torch.manual_seed(0)

# choose robot alongside joint limits
robot_choice = "2DoF-2R"
"""
q_lim = torch.tensor([[-torch.pi, torch.pi],
                      [-torch.pi, torch.pi]])
"""

q_lim = torch.tensor([[0, torch.pi],
                      [0, torch.pi]])

# generate dataset with a specified number of samples
n_samples = 10000
data_position = []
for _ in range(n_samples):
    t = torch.distributions.uniform.Uniform(q_lim[:,0], q_lim[:,1]).sample()
    DH = get_DH(robot_choice, t)
    T = forward_kinematics(DH)
    if robot_choice == "2DoF-2R":
        # x,y,t1,t2,t3 where x,y (m) and t (rad)
        data_position.append(torch.cat([T[:2,-1], t]).numpy())
      
data_position_a = np.array(data_position)


# save dataset
if robot_choice == "2DoF-2R":
    header = ["x","y","t1","t2"]
    
df = pd.DataFrame(data_position_a)
df.to_csv("data_"+robot_choice+".csv",
          index=False,
          header=header)

# %% [markdown]
# # Torch Training

# %%
import torch
# import torchga
import pygad.torchga as torchga

def fitness_func(ga_instance, solution, sol_idx):
    global data_inputs, data_outputs, torch_ga, model, loss_function

    model_weights_dict = torchga.model_weights_as_dict(model=model,
                                                       weights_vector=solution)

    # Use the current solution as the model parameters.
    model.load_state_dict(model_weights_dict)

    predictions = model(data_inputs)
#     abs_error = loss_function(predictions, data_outputs).detach().numpy() + 0.00000001
    abs_error = loss_function(predictions, data_outputs).detach().numpy()

#     solution_fitness = 1.0 / abs_error
    solution_fitness = -abs_error

    return solution_fitness

def callback_generation(ga_instance):
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))

# Create the PyTorch model.
input_layer = torch.nn.Linear(2, 5)
relu_layer = torch.nn.ReLU()
sigmoid_layer = torch.nn.Sigmoid()
h1 = torch.nn.Linear(5, 128)
h2 = torch.nn.Linear(128, 512)
h3 = torch.nn.Linear(512, 128)
h4 = torch.nn.Linear(128, 5)
output_layer = torch.nn.Linear(5, 3)

model = torch.nn.Sequential(input_layer,
                            sigmoid_layer,
                            h1,
                            sigmoid_layer,
                            h2,
                            sigmoid_layer,
                            h3,
                            sigmoid_layer,
                            h4,
                            relu_layer,
                            output_layer)
# print(model)

# Create an instance of the pygad.torchga.TorchGA class to build the initial population.
torch_ga = torchga.TorchGA(model=model,
                           num_solutions=10)

loss_function = torch.nn.L1Loss()

# Data inputs


training_data = data_position_a[:8000, :2]
testing_data = data_position_a[8000:, :2]

training_targets = data_position_a[:8000, 2:]
testing_targets = data_position_a[8000:, 2:]

data_inputs = torch.from_numpy(training_data)
data_outputs = torch.from_numpy(training_targets)

# data_inputs = torch.tensor([[0.02, 0.1, 0.15],
#                             [0.7, 0.6, 0.8],
#                             [1.5, 1.2, 1.7],
#                             [3.2, 2.9, 3.1]])

# # Data outputs
# data_outputs = torch.tensor([[0.1],
#                              [0.6],
#                              [1.3],
#                              [2.5]])

# Prepare the PyGAD parameters. Check the documentation for more information: https://pygad.readthedocs.io/en/latest/pygad.html#pygad-ga-class
num_generations = 250 # Number of generations.
num_parents_mating = 5 # Number of solutions to be selected as parents in the mating pool.
initial_population = torch_ga.population_weights # Initial population of network weights

ga_instance = pygad.GA(num_generations=num_generations, 
                       num_parents_mating=num_parents_mating, 
                       initial_population=initial_population,
                       fitness_func=fitness_func,
                       on_generation=callback_generation)

ga_instance.run()

# After the generations complete, some plots are showed that summarize how the outputs/fitness values evolve over generations.
ga_instance.plot_fitness(title="PyGAD & PyTorch - Iteration vs. Fitness", linewidth=4)

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

# Fetch the parameters of the best solution.
best_solution_weights = torchga.model_weights_as_dict(model=model,
                                                      weights_vector=solution)
model.load_state_dict(best_solution_weights)
predictions = model(data_inputs)
print("Predictions : \n", predictions.detach().numpy())

abs_error = loss_function(predictions, data_outputs)
print("Absolute Error : ", abs_error.detach().numpy())
# Out:
# Generation = 1
# Fitness    = -1.571385383605957
# Generation = 2
# Fitness    = -1.571385383605957
# Generation = 3
# Fitness    = -1.571385383605957
# Generation = 4
# Fitness    = -1.571385383605957
# Generation = 5
# Fitness    = -1.5699213743209839
# Generation = 6
# Fitness    = -1.5699213743209839
# Generation = 7
# Fitness    = -1.568060278892517
# Generation = 8
# Fitness    = -1.568060278892517
# Generation = 9
# Fitness    = -1.5413222312927246
# Generation = 10
# Fitness    = -1.5413222312927246
# Generation = 11
# Fitness    = -1.5413222312927246
# Generation = 12
# Fitness    = -1.5413222312927246
# Generation = 13
# Fitness    = -1.5413222312927246
# Generation = 14
# Fitness    = -1.5220046043395996
# Generation = 15
# Fitness    = -1.5220046043395996
# Generation = 16
# Fitness    = -1.5220046043395996
# Generation = 17
# Fitness    = -1.5220046043395996
# Generation = 18
# Fitness    = -1.5220046043395996
# Generation = 19
# Fitness    = -1.5220046043395996
# Generation = 20
# Fitness    = -1.5073089599609375
# Generation = 21
# Fitness    = -1.5073089599609375
# Generation = 22
# Fitness    = -1.5073089599609375
# Generation = 23
# Fitness    = -1.5073089599609375
# Generation = 24
# Fitness    = -1.5073089599609375
# Generation = 25
# Fitness    = -1.5073089599609375
# Generation = 26
# Fitness    = -1.5073089599609375
# Generation = 27
# Fitness    = -1.5073089599609375
# Generation = 28
# Fitness    = -1.5073089599609375
# Generation = 29
# Fitness    = -1.5073089599609375
# Generation = 30
# Fitness    = -1.5073089599609375
# Generation = 31
# Fitness    = -1.5073089599609375
# Generation = 32
# Fitness    = -1.5073089599609375
# Generation = 33
# Fitness    = -1.5073089599609375
# Generation = 34
# Fitness    = -1.5073089599609375
# Generation = 35
# Fitness    = -1.5073089599609375
# Generation = 36
# Fitness    = -1.5073089599609375
# Generation = 37
# Fitness    = -1.5073089599609375
# Generation = 38
# Fitness    = -1.5073089599609375
# Generation = 39
# Fitness    = -1.5073089599609375
# Generation = 40
# Fitness    = -1.5073089599609375
# Generation = 41
# Fitness    = -1.5073089599609375
# Generation = 42
# Fitness    = -1.5073089599609375
# Generation = 43
# Fitness    = -1.5073089599609375
# Generation = 44
# Fitness    = -1.4848392009735107
# Generation = 45
# Fitness    = -1.4848392009735107
# Generation = 46
# Fitness    = -1.4848392009735107
# Generation = 47
# Fitness    = -1.4848392009735107
# Generation = 48
# Fitness    = -1.4848392009735107
# Generation = 49
# Fitness    = -1.4848392009735107
# Generation = 50
# Fitness    = -1.4848392009735107
# Generation = 51
# Fitness    = -1.4848392009735107
# Generation = 52
# Fitness    = -1.4848392009735107
# Generation = 53
# Fitness    = -1.4848392009735107
# Generation = 54
# Fitness    = -1.4848392009735107
# Generation = 55
# Fitness    = -1.4848392009735107
# Generation = 56
# Fitness    = -1.4848392009735107
# Generation = 57
# Fitness    = -1.4848392009735107
# Generation = 58
# Fitness    = -1.4848392009735107
# Generation = 59
# Fitness    = -1.4848392009735107
# Generation = 60
# Fitness    = -1.4848392009735107
# Generation = 61
# Fitness    = -1.4848392009735107
# Generation = 62
# Fitness    = -1.4848392009735107
# Generation = 63
# Fitness    = -1.4848392009735107
# Generation = 64
# Fitness    = -1.4848392009735107
# Generation = 65
# Fitness    = -1.4848392009735107
# Generation = 66
# Fitness    = -1.4848392009735107
# Generation = 67
# Fitness    = -1.4848392009735107
# Generation = 68
# Fitness    = -1.4848392009735107
# Generation = 69
# Fitness    = -1.4848392009735107
# Generation = 70
# Fitness    = -1.4848392009735107
# Generation = 71
# Fitness    = -1.4848392009735107
# Generation = 72
# Fitness    = -1.4848392009735107
# Generation = 73
# Fitness    = -1.4848392009735107
# Generation = 74
# Fitness    = -1.4848392009735107
# Generation = 75
# Fitness    = -1.4848392009735107
# Generation = 76
# Fitness    = -1.4848392009735107
# Generation = 77
# Fitness    = -1.4848392009735107
# Generation = 78
# Fitness    = -1.4848392009735107
# Generation = 79
# Fitness    = -1.4848392009735107
# Generation = 80
# Fitness    = -1.4848392009735107
# Generation = 81
# Fitness    = -1.4848392009735107
# Generation = 82
# Fitness    = -1.4848392009735107
# Generation = 83
# Fitness    = -1.4848392009735107
# Generation = 84
# Fitness    = -1.4848392009735107
# Generation = 85
# Fitness    = -1.4848392009735107
# Generation = 86
# Fitness    = -1.4848392009735107
# Generation = 87
# Fitness    = -1.4848392009735107
# Generation = 88
# Fitness    = -1.4848392009735107
# Generation = 89
# Fitness    = -1.4848392009735107
# Generation = 90
# Fitness    = -1.4848392009735107
# Generation = 91
# Fitness    = -1.4848392009735107
# Generation = 92
# Fitness    = -1.4848392009735107
# Generation = 93
# Fitness    = -1.4848392009735107
# Generation = 94
# Fitness    = -1.4848392009735107
# Generation = 95
# Fitness    = -1.4848392009735107
# Generation = 96
# Fitness    = -1.4848392009735107
# Generation = 97
# Fitness    = -1.4848392009735107
# Generation = 98
# Fitness    = -1.4848392009735107
# Generation = 99
# Fitness    = -1.4848392009735107
# Generation = 100
# Fitness    = -1.4848392009735107
# Generation = 101
# Fitness    = -1.4848392009735107
# Generation = 102
# Fitness    = -1.4848392009735107
# Generation = 103
# Fitness    = -1.4848392009735107
# Generation = 104
# Fitness    = -1.4848392009735107
# Generation = 105
# Fitness    = -1.4848392009735107
# Generation = 106
# Fitness    = -1.4848392009735107
# Generation = 107
# Fitness    = -1.4848392009735107
# Generation = 108
# Fitness    = -1.4848392009735107
# Generation = 109
# Fitness    = -1.4848392009735107
# Generation = 110
# Fitness    = -1.4848392009735107
# Generation = 111
# Fitness    = -1.4848392009735107
# Generation = 112
# Fitness    = -1.4848392009735107
# Generation = 113
# Fitness    = -1.4848392009735107
# Generation = 114
# Fitness    = -1.4848392009735107
# Generation = 115
# Fitness    = -1.4848392009735107
# Generation = 116
# Fitness    = -1.4848392009735107
# Generation = 117
# Fitness    = -1.4848392009735107
# Generation = 118
# Fitness    = -1.4848392009735107
# Generation = 119
# Fitness    = -1.4848392009735107
# Generation = 120
# Fitness    = -1.4848392009735107
# Generation = 121
# Fitness    = -1.4848392009735107
# Generation = 122
# Fitness    = -1.4848392009735107
# Generation = 123
# Fitness    = -1.4848392009735107
# Generation = 124
# Fitness    = -1.4848392009735107
# Generation = 125
# Fitness    = -1.4848392009735107
# Generation = 126
# Fitness    = -1.4848392009735107
# Generation = 127
# Fitness    = -1.4848392009735107
# Generation = 128
# Fitness    = -1.4848392009735107
# Generation = 129
# Fitness    = -1.4848392009735107
# Generation = 130
# Fitness    = -1.4848392009735107
# Generation = 131
# Fitness    = -1.4848392009735107
# Generation = 132
# Fitness    = -1.4848392009735107
# Generation = 133
# Fitness    = -1.4848392009735107
# Generation = 134
# Fitness    = -1.4848392009735107
# Generation = 135
# Fitness    = -1.4848392009735107
# Generation = 136
# Fitness    = -1.4848392009735107
# Generation = 137
# Fitness    = -1.4848392009735107
# Generation = 138
# Fitness    = -1.4848392009735107
# Generation = 139
# Fitness    = -1.4848392009735107
# Generation = 140
# Fitness    = -1.4848392009735107
# Generation = 141
# Fitness    = -1.4848392009735107
# Generation = 142
# Fitness    = -1.4848392009735107
# Generation = 143
# Fitness    = -1.4848392009735107
# Generation = 144
# Fitness    = -1.4848392009735107
# Generation = 145
# Fitness    = -1.4848392009735107
# Generation = 146
# Fitness    = -1.4848392009735107
# Generation = 147
# Fitness    = -1.4848392009735107
# Generation = 148
# Fitness    = -1.4848392009735107
# Generation = 149
# Fitness    = -1.4848392009735107
# Generation = 150
# Fitness    = -1.4848392009735107
# Generation = 151
# Fitness    = -1.4848392009735107
# Generation = 152
# Fitness    = -1.4848392009735107
# Generation = 153
# Fitness    = -1.4848392009735107
# Generation = 154
# Fitness    = -1.4848392009735107
# Generation = 155
# Fitness    = -1.4848392009735107
# Generation = 156
# Fitness    = -1.4848392009735107
# Generation = 157
# Fitness    = -1.4848392009735107
# Generation = 158
# Fitness    = -1.4848392009735107
# Generation = 159
# Fitness    = -1.4848392009735107
# Generation = 160
# Fitness    = -1.4848392009735107
# Generation = 161
# Fitness    = -1.4848392009735107
# Generation = 162
# Fitness    = -1.4848392009735107
# Generation = 163
# Fitness    = -1.4848392009735107
# Generation = 164
# Fitness    = -1.4848392009735107
# Generation = 165
# Fitness    = -1.4848392009735107
# Generation = 166
# Fitness    = -1.4848392009735107
# Generation = 167
# Fitness    = -1.4848392009735107
# Generation = 168
# Fitness    = -1.4848392009735107
# Generation = 169
# Fitness    = -1.4848392009735107
# Generation = 170
# Fitness    = -1.4848392009735107
# Generation = 171
# Fitness    = -1.4848392009735107
# Generation = 172
# Fitness    = -1.4848392009735107
# Generation = 173
# Fitness    = -1.4848392009735107
# Generation = 174
# Fitness    = -1.4848392009735107
# Generation = 175
# Fitness    = -1.4848392009735107
# Generation = 176
# Fitness    = -1.4848392009735107
# Generation = 177
# Fitness    = -1.4848392009735107
# Generation = 178
# Fitness    = -1.4848392009735107
# Generation = 179
# Fitness    = -1.4848392009735107
# Generation = 180
# Fitness    = -1.4848392009735107
# Generation = 181
# Fitness    = -1.4848392009735107
# Generation = 182
# Fitness    = -1.4848392009735107
# Generation = 183
# Fitness    = -1.4848392009735107
# Generation = 184
# Fitness    = -1.4848392009735107
# Generation = 185
# Fitness    = -1.4848392009735107
# Generation = 186
# Fitness    = -1.4848392009735107
# Generation = 187
# Fitness    = -1.4848392009735107
# Generation = 188
# Fitness    = -1.4848392009735107
# Generation = 189
# Fitness    = -1.4848392009735107
# Generation = 190
# Fitness    = -1.4848392009735107
# Generation = 191
# Fitness    = -1.4848392009735107
# Generation = 192
# Fitness    = -1.4848392009735107
# Generation = 193
# Fitness    = -1.4848392009735107
# Generation = 194
# Fitness    = -1.4848392009735107
# Generation = 195
# Fitness    = -1.4848392009735107
# Generation = 196
# Fitness    = -1.4848392009735107
# Generation = 197
# Fitness    = -1.4848392009735107
# Generation = 198
# Fitness    = -1.4848392009735107
# Generation = 199
# Fitness    = -1.4848392009735107
# Generation = 200
# Fitness    = -1.4848392009735107
# Generation = 201
# Fitness    = -1.4848392009735107
# Generation = 202
# Fitness    = -1.4848392009735107
# Generation = 203
# Fitness    = -1.4848392009735107
# Generation = 204
# Fitness    = -1.4848392009735107
# Generation = 205
# Fitness    = -1.4848392009735107
# Generation = 206
# Fitness    = -1.4848392009735107
# Generation = 207
# Fitness    = -1.4848392009735107
# Generation = 208
# Fitness    = -1.4848392009735107
# Generation = 209
# Fitness    = -1.4848392009735107
# Generation = 210
# Fitness    = -1.4848392009735107
# Generation = 211
# Fitness    = -1.4848392009735107
# Generation = 212
# Fitness    = -1.4848392009735107
# Generation = 213
# Fitness    = -1.4848392009735107
# Generation = 214
# Fitness    = -1.4848392009735107
# Generation = 215
# Fitness    = -1.4848392009735107
# Generation = 216
# Fitness    = -1.4848392009735107
# Generation = 217
# Fitness    = -1.4848392009735107
# Generation = 218
# Fitness    = -1.4848392009735107
# Generation = 219
# Fitness    = -1.4848392009735107
# Generation = 220
# Fitness    = -1.4848392009735107
# Generation = 221
# Fitness    = -1.4848392009735107
# Generation = 222
# Fitness    = -1.4848392009735107
# Generation = 223
# Fitness    = -1.4848392009735107
# Generation = 224
# Fitness    = -1.4848392009735107
# Generation = 225
# Fitness    = -1.4848392009735107
# Generation = 226
# Fitness    = -1.4848392009735107
# Generation = 227
# Fitness    = -1.4848392009735107
# Generation = 228
# Fitness    = -1.4848392009735107
# Generation = 229
# Fitness    = -1.4848392009735107
# Generation = 230
# Fitness    = -1.4848392009735107
# Generation = 231
# Fitness    = -1.4848392009735107
# Generation = 232
# Fitness    = -1.4848392009735107
# Generation = 233
# Fitness    = -1.4848392009735107
# Generation = 234
# Fitness    = -1.4848392009735107
# Generation = 235
# Fitness    = -1.4848392009735107
# Generation = 236
# Fitness    = -1.4848392009735107
# Generation = 237
# Fitness    = -1.4848392009735107
# Generation = 238
# Fitness    = -1.4848392009735107
# Generation = 239
# Fitness    = -1.4848392009735107
# Generation = 240
# Fitness    = -1.4848392009735107
# Generation = 241
# Fitness    = -1.4848392009735107
# Generation = 242
# Fitness    = -1.4848392009735107
# Generation = 243
# Fitness    = -1.4848392009735107
# Generation = 244
# Fitness    = -1.4848392009735107
# Generation = 245
# Fitness    = -1.4848392009735107
# Generation = 246
# Fitness    = -1.4848392009735107
# Generation = 247
# Fitness    = -1.4848392009735107
# Generation = 248
# Fitness    = -1.4848392009735107
# Generation = 249
# Fitness    = -1.4848392009735107
# Generation = 250
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Fitness    = -1.4848392009735107
# Fitness value of the best solution = -1.4848392009735107
# Index of the best solution : 0
# Predictions :
#  [[ 0.40376478  0.3074476  -0.3446847 ]
#  [-1.4118807  -0.31802815  0.06877175]
#  [ 0.40376478  0.3074476  -0.3446847 ]
#  ...
#  [-1.1391232  -0.45469552 -0.05581024]
#  [ 0.40376478  0.3074476  -0.3446847 ]
#  [ 0.40376478  0.3074476  -0.3446847 ]]
# Absolute Error :  1.4848392

# %%
solution.shape
# Out:
# (148,)
